# %%
import pandas as pd
# !pip install ntscraper

# %%
from ntscraper import Nitter

# %%
scraper = Nitter(log_level=1, skip_instance_check= False)
# Out:
# Testing instances: 100%|██████████| 16/16 [00:20<00:00,  1.30s/it]

# %%
tweets = scraper.get_tweets("'93_اليوم_الوطني'", mode = 'hashtag', number=700)
# Out:
# INFO:root:No instance specified, using random instance https://nitter.lucabased.xyz
# INFO:root:Current stats for '93_اليوم_الوطني': 5 tweets, 0 threads...
# INFO:root:Current stats for '93_اليوم_الوطني': 13 tweets, 0 threads...
# INFO:root:Current stats for '93_اليوم_الوطني': 29 tweets, 0 threads...
# INFO:root:Current stats for '93_اليوم_الوطني': 37 tweets, 0 threads...
# INFO:root:Current stats for '93_اليوم_الوطني': 46 tweets, 0 threads...
# INFO:root:Current stats for '93_اليوم_الوطني': 52 tweets, 0 threads...
# INFO:root:Current stats for '93_اليوم_الوطني': 59 tweets, 0 threads...
# INFO:root:Current stats for '93_اليوم_الوطني': 63 tweets, 0 threads...
# INFO:root:Current stats for '93_اليوم_الوطني': 75 tweets, 0 threads...
# INFO:root:Current stats for '93_اليوم_الوطني': 83 tweets, 0 threads...
# INFO:root:Current stats for '93_اليوم_الوطني': 93 tweets, 0 threads...
# INFO:root:Current stats for '93_اليوم_الوطني': 98 tweets, 0 threads...
# ...

# %%
final_tweets = []
for x in tweets['tweets']:
    data = [x['link'], x['text'],x['date'],x['stats']['likes'],x['stats']['comments']]
    final_tweets.append(data)

# %%
dat = pd.DataFrame(final_tweets, columns =['twitter_link','text','date','likes','comments'])

# %%
dat
# Out:
#                                           twitter_link  \
# 0    https://twitter.com/KSA88JED/status/1833237168...
# 1    https://twitter.com/Ff55_fe/status/18328232533...
# 2    https://twitter.com/K_wmks/status/170511437153...
# 3    https://twitter.com/Hla62528518/status/1705544...
# 4    https://twitter.com/ZaidAlsalman6/status/18332...
# ..                                                 ...
# 394  https://twitter.com/uhuhhb43418/status/1814027...
# 395  https://twitter.com/Dama_Post_syria/status/181...
# 396  https://twitter.com/Memo62241322/status/181279...
# 397  https://twitter.com/Moustafa_Mo93/status/18114...
# 398  https://twitter.com/MhmadKulla92841/status/180...
#
#                                                   text  \
# 0    عز الله ماقصرت بسهم اليوم الوطني 93 انابيب الش...
# 1    بمناسبة #اليوم_الوطني_السعودي94  سحب على 65 سي...
# 2    في العيد الوطني رقم 93 ؛ أشعر بكل الفخر والسرو...
# 3    دام عزك يا وطني ودُمت متفرداً بالحُب والعطاء م...
# ...

# %%
from google.colab import files
dat.to_excel('x398.xlsx')
files.download('x398.xlsx')
